# %%
import pandas as pd
import mlflow

## NOTE: You can use Microsoft Azure Machine Learning Studio for experiment tracking. Follow assignment description and 
# uncomment below for that (you might also need to pip azureml (pip install azureml-core):
from azureml.core import Workspace
ws = Workspace.from_config()
mlflow.set_tracking_uri(ws.get_mlflow_tracking_uri())

## NOTE: Optionally, you can use the public tracking server.  Do not use it for data you cannot afford to lose. See note in assignment text. If you leave this line as a comment, mlflow will save the runs to your local filesystem.

# mlflow.set_tracking_uri("http://training.itu.dk:5000/")

# TODO: Set the experiment name
mlflow.set_experiment("<ITU Username> - <Descriptive experiment name>")

# Import some of the sklearn modules you are likely to use.
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Start a run
# TODO: Set a descriptive name. This is optional, but makes it easier to keep track of your runs.
with mlflow.start_run(run_name="<descriptive name>"):
    # TODO: Insert path to dataset
    df = pd.read_json("path/to/dataset.json", orient="split")

    # TODO: Handle missing data

    pipeline = Pipeline([
        # TODO: You can start with your pipeline from assignment 1
    ])

    # TODO: Currently the only metric is MAE. You should add more. What other metrics could you use? Why?
    metrics = [
        ("MAE", mean_absolute_error, []),
    ]

    X = df[["Speed","Direction"]]
    y = df["Total"]

    number_of_splits = 5

    #TODO: Log your parameters. What parameters are important to log?
    #HINT: You can get access to the transformers in your pipeline using `pipeline.steps`
    
    for train, test in TimeSeriesSplit(number_of_splits).split(X,y):
        pipeline.fit(X.iloc[train],y.iloc[train])
        predictions = pipeline.predict(X.iloc[test])
        truth = y.iloc[test]

        from matplotlib import pyplot as plt 
        plt.plot(truth.index, truth.values, label="Truth")
        plt.plot(truth.index, predictions, label="Predictions")
        plt.show()
        
        # Calculate and save the metrics for this fold
        for name, func, scores in metrics:
            score = func(truth, predictions)
            scores.append(score)
    
    # Log a summary of the metrics
    for name, _, scores in metrics:
            # NOTE: Here we just log the mean of the scores. 
            # Are there other summarizations that could be interesting?
            mean_score = sum(scores)/number_of_splits
            mlflow.log_metric(f"mean_{name}", mean_score)
# Out:
# ---------------------------------------------------------------------------
# UserErrorException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8936/2536700432.py in <module>
#       5 # uncomment below for that (you might also need to pip azureml (pip install azureml-core):
#       6 from azureml.core import Workspace
# ----> 7 ws = Workspace.from_config()
#       8 #mlflow.set_tracking_uri(ws.get_mlflow_tracking_uri())
#       9
#
# c:\users\music\appdata\local\programs\python\python39\lib\site-packages\azureml\core\workspace.py in from_config(path, auth, _logger, _file_name)
#     277
#     278             if not found_path:
# --> 279                 raise UserErrorException(
#     280                     "The workspace configuration file config.json, could not be found in {} or its parent "
#     281                     "directories. Please check whether the workspace configuration file exists, or provide "
#
# UserErrorException: UserErrorException:
# 	Message: The workspace configuration file config.json, could not be found in D:\ITU-BOOK\ITU\LARGE SCALE\AS3 or its parent directories. Please check whether the workspace configuration file exists, or provide the full path to the configuration file as an argument. You can download a configuration file for your workspace, via http://ml.azure.com and clicking on the name of your workspace in the right top.
# 	InnerException None
# 	ErrorResponse
# {
#     "error": {
#         "code": "UserError",
#         "message": "The workspace configuration file config.json, could not be found in D:\\ITU-BOOK\\ITU\\LARGE SCALE\\AS3 or its parent directories. Please check whether the workspace configuration file exists, or provide the full path to the configuration file as an argument. You can download a configuration file for your workspace, via http://ml.azure.com and clicking on the name of your workspace in the right top."
#     }
# }

# %%
from azureml.core import Workspace
ws = Workspace.from_config()
mlflow.set_tracking_uri(ws.get_mlflow_tracking_uri())

# %%
mlflow.set_tracking_uri("https://training.itu.dk:5000/")

# %%
mlflow.set_experiment("<gegy> - <trial>")
# Out:
# 2022/05/02 14:22:43 INFO mlflow.tracking.fluent: Experiment with name '<gegy> - <trial>' does not exist. Creating a new experiment.
# <Experiment: artifact_location='s3://training-storage/123', experiment_id='123', lifecycle_stage='active', name='<gegy> - <trial>', tags={}>

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Start a run
# TODO: Set a descriptive name. This is optional, but makes it easier to keep track of your runs.
with mlflow.start_run(run_name="he"):
    # TODO: Insert path to dataset
    df = pd.read_json("path/to/dataset.json", orient="split")

    # TODO: Handle missing data
    df.dropna(inplace = True)

    pipeline = Pipeline([
        # TODO: You can start with your pipeline from assignment 1
    ])

    # TODO: Currently the only metric is MAE. You should add more. What other metrics could you use? Why?
    metrics = [
        ("MAE", mean_absolute_error, []),
    ]

    X = df[["Speed","Direction"]]
    y = df["Total"]

    number_of_splits = 5

    #TODO: Log your parameters. What parameters are important to log?
    #HINT: You can get access to the transformers in your pipeline using `pipeline.steps`
    
    for train, test in TimeSeriesSplit(number_of_splits).split(X,y):
        pipeline.fit(X.iloc[train],y.iloc[train])
        predictions = pipeline.predict(X.iloc[test])
        truth = y.iloc[test]

        from matplotlib import pyplot as plt 
        plt.plot(truth.index, truth.values, label="Truth")
        plt.plot(truth.index, predictions, label="Predictions")
        plt.show()
        
        # Calculate and save the metrics for this fold
        for name, func, scores in metrics:
            score = func(truth, predictions)
            scores.append(score)
    
    # Log a summary of the metrics
    for name, _, scores in metrics:
            # NOTE: Here we just log the mean of the scores. 
            # Are there other summarizations that could be interesting?
            mean_score = sum(scores)/number_of_splits
            mlflow.log_metric(f"mean_{name}", mean_score)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8936/109617460.py in <module>
#      15     # TODO: Handle missing data
#      16
# ---> 17     pipeline = Pipeline([
#      18         # TODO: You can start with your pipeline from assignment 1
#      19     ])
#
# c:\users\music\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\users\music\appdata\local\programs\python\python39\lib\site-packages\sklearn\pipeline.py in __init__(self, steps, memory, verbose)
#     116         self.memory = memory
#     117         self.verbose = verbose
# --> 118         self._validate_steps()
#     119
#     120     def get_params(self, deep=True):
#
# c:\users\music\appdata\local\programs\python\python39\lib\site-packages\sklearn\pipeline.py in _validate_steps(self)
#     152
#     153     def _validate_steps(self):
# --> 154         names, estimators = zip(*self.steps)
#     155
#     156         # validate names
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
df = pd.read_json("path/to/dataset.json", orient="split")

# %%
df
# Out:
#                           ANM  Non-ANM      Total Direction  Lead_hours  \
# 2020-10-09 12:31:00  2.355000    5.000   7.355000      None         NaN
# 2020-10-09 12:32:00  2.475000    4.043   6.518000      None         NaN
# 2020-10-09 12:33:00  2.633000    4.514   7.147000      None         NaN
# 2020-10-09 12:34:00  3.014000    4.235   7.249000      None         NaN
# 2020-10-09 12:35:00  3.180000    3.601   6.781000      None         NaN
# ...                       ...      ...        ...       ...         ...
# 2021-04-07 12:26:00  7.117000    9.637  16.754000      None         NaN
# 2021-04-07 12:27:00  7.404000    8.851  16.255000      None         NaN
# 2021-04-07 12:28:00  7.332000    8.795  16.127000      None         NaN
# 2021-04-07 12:29:00  7.894002    8.542  16.436002      None         NaN
# 2021-04-07 12:30:00  7.845999    8.804  16.649999      None         NaN
#
#                     Source_time  Speed
# 2020-10-09 12:31:00         NaT    NaN
# 2020-10-09 12:32:00         NaT    NaN
# 2020-10-09 12:33:00         NaT    NaN
# 2020-10-09 12:34:00         NaT    NaN
# 2020-10-09 12:35:00         NaT    NaN
# ...                         ...    ...
# 2021-04-07 12:26:00         NaT    NaN
# 2021-04-07 12:27:00         NaT    NaN
# 2021-04-07 12:28:00         NaT    NaN
# 2021-04-07 12:29:00         NaT    NaN
# 2021-04-07 12:30:00         NaT    NaN
#
# [254933 rows x 7 columns]

# %%
df[df["Direction"] == ""]
# Out:
# Empty DataFrame
# Columns: [ANM, Non-ANM, Total, Direction, Lead_hours, Source_time, Speed]
# Index: []

# %%
df[df["ANM"] > 3]
# Out:
#                           ANM  Non-ANM      Total Direction  Lead_hours  \
# 2020-10-09 12:34:00  3.014000    4.235   7.249000      None         NaN
# 2020-10-09 12:35:00  3.180000    3.601   6.781000      None         NaN
# 2020-10-09 12:36:00  3.262000    3.689   6.951000      None         NaN
# 2020-10-09 12:37:00  3.201000    3.923   7.124000      None         NaN
# 2020-10-09 12:38:00  3.301000    4.172   7.473000      None         NaN
# ...                       ...      ...        ...       ...         ...
# 2021-04-07 12:26:00  7.117000    9.637  16.754000      None         NaN
# 2021-04-07 12:27:00  7.404000    8.851  16.255000      None         NaN
# 2021-04-07 12:28:00  7.332000    8.795  16.127000      None         NaN
# 2021-04-07 12:29:00  7.894002    8.542  16.436002      None         NaN
# 2021-04-07 12:30:00  7.845999    8.804  16.649999      None         NaN
#
#                     Source_time  Speed
# 2020-10-09 12:34:00         NaT    NaN
# 2020-10-09 12:35:00         NaT    NaN
# 2020-10-09 12:36:00         NaT    NaN
# 2020-10-09 12:37:00         NaT    NaN
# 2020-10-09 12:38:00         NaT    NaN
# ...                         ...    ...
# 2021-04-07 12:26:00         NaT    NaN
# 2021-04-07 12:27:00         NaT    NaN
# 2021-04-07 12:28:00         NaT    NaN
# 2021-04-07 12:29:00         NaT    NaN
# 2021-04-07 12:30:00         NaT    NaN
#
# [180525 rows x 7 columns]

# %%
df["Direction"][1]

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#                            ANM  Non-ANM      Total Direction  Lead_hours  \
# 2020-10-09 15:00:00   4.482000    5.238   9.720000        NW         1.0
# 2020-10-09 18:00:00   5.227999    9.005  14.232999        NW         1.0
# 2020-10-09 21:00:00   2.253000    3.750   6.003000       WNW         1.0
# 2020-10-10 00:00:00   2.091000    1.893   3.984000       WNW         1.0
# 2020-10-10 03:00:00   0.142000    1.476   1.618000       NNW         1.0
# ...                        ...      ...        ...       ...         ...
# 2021-04-07 00:00:00  14.335996   18.732  33.067996       NNW         1.0
# 2021-04-07 03:00:00  14.459997   18.437  32.896997         N         1.0
# 2021-04-07 06:00:00  13.791000   18.058  31.849000       NNW         1.0
# 2021-04-07 09:00:00  11.447002   14.395  25.842002        NW         1.0
# 2021-04-07 12:00:00   7.514001    9.418  16.932001       NNW         1.0
#
#                             Source_time     Speed
# 2020-10-09 15:00:00 2020-10-09 12:00:00   5.81152
# 2020-10-09 18:00:00 2020-10-09 15:00:00   5.81152
# 2020-10-09 21:00:00 2020-10-09 18:00:00   4.91744
# 2020-10-10 00:00:00 2020-10-09 21:00:00   5.81152
# 2020-10-10 03:00:00 2020-10-10 00:00:00   3.12928
# ...                                 ...       ...
# 2021-04-07 00:00:00 2021-04-06 21:00:00  15.19936
# 2021-04-07 03:00:00 2021-04-07 00:00:00  13.85824
# 2021-04-07 06:00:00 2021-04-07 03:00:00  13.85824
# 2021-04-07 09:00:00 2021-04-07 06:00:00   8.04672
# 2021-04-07 12:00:00 2021-04-07 09:00:00   7.15264
#
# [1318 rows x 7 columns]

# %%
df.mask(df.Direction != "None")
# Out:
#                      ANM  Non-ANM  Total Direction  Lead_hours Source_time  \
# 2020-10-09 12:31:00  NaN      NaN    NaN       NaN         NaN         NaT
# 2020-10-09 12:32:00  NaN      NaN    NaN       NaN         NaN         NaT
# 2020-10-09 12:33:00  NaN      NaN    NaN       NaN         NaN         NaT
# 2020-10-09 12:34:00  NaN      NaN    NaN       NaN         NaN         NaT
# 2020-10-09 12:35:00  NaN      NaN    NaN       NaN         NaN         NaT
# ...                  ...      ...    ...       ...         ...         ...
# 2021-04-07 12:26:00  NaN      NaN    NaN       NaN         NaN         NaT
# 2021-04-07 12:27:00  NaN      NaN    NaN       NaN         NaN         NaT
# 2021-04-07 12:28:00  NaN      NaN    NaN       NaN         NaN         NaT
# 2021-04-07 12:29:00  NaN      NaN    NaN       NaN         NaN         NaT
# 2021-04-07 12:30:00  NaN      NaN    NaN       NaN         NaN         NaT
#
#                      Speed
# 2020-10-09 12:31:00    NaN
# 2020-10-09 12:32:00    NaN
# 2020-10-09 12:33:00    NaN
# 2020-10-09 12:34:00    NaN
# 2020-10-09 12:35:00    NaN
# ...                    ...
# 2021-04-07 12:26:00    NaN
# 2021-04-07 12:27:00    NaN
# 2021-04-07 12:28:00    NaN
# 2021-04-07 12:29:00    NaN
# 2021-04-07 12:30:00    NaN
#
# [254933 rows x 7 columns]

# %%
df
# Out:
#                           ANM  Non-ANM      Total Direction  Lead_hours  \
# 2020-10-09 12:31:00  2.355000    5.000   7.355000      None         NaN
# 2020-10-09 12:32:00  2.475000    4.043   6.518000      None         NaN
# 2020-10-09 12:33:00  2.633000    4.514   7.147000      None         NaN
# 2020-10-09 12:34:00  3.014000    4.235   7.249000      None         NaN
# 2020-10-09 12:35:00  3.180000    3.601   6.781000      None         NaN
# ...                       ...      ...        ...       ...         ...
# 2021-04-07 12:26:00  7.117000    9.637  16.754000      None         NaN
# 2021-04-07 12:27:00  7.404000    8.851  16.255000      None         NaN
# 2021-04-07 12:28:00  7.332000    8.795  16.127000      None         NaN
# 2021-04-07 12:29:00  7.894002    8.542  16.436002      None         NaN
# 2021-04-07 12:30:00  7.845999    8.804  16.649999      None         NaN
#
#                     Source_time  Speed
# 2020-10-09 12:31:00         NaT    NaN
# 2020-10-09 12:32:00         NaT    NaN
# 2020-10-09 12:33:00         NaT    NaN
# 2020-10-09 12:34:00         NaT    NaN
# 2020-10-09 12:35:00         NaT    NaN
# ...                         ...    ...
# 2021-04-07 12:26:00         NaT    NaN
# 2021-04-07 12:27:00         NaT    NaN
# 2021-04-07 12:28:00         NaT    NaN
# 2021-04-07 12:29:00         NaT    NaN
# 2021-04-07 12:30:00         NaT    NaN
#
# [254933 rows x 7 columns]

# %%
df["Direction"] != "None"
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# c:\users\music\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion._convert_str_to_tsobject()
#
# c:\users\music\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# c:\users\music\appdata\local\programs\python\python39\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1367     else:
# -> 1368         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1369
#
# c:\users\music\appdata\local\programs\python\python39\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     642         if res is None:
# --> 643             raise ParserError("Unknown string format: %s", timestr)
#     644
#
# ParserError: Unknown string format: Direction
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# c:\users\music\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\datetimes.py in get_loc(self, key, method, tolerance)
#     680             try:
# --> 681                 key = self._maybe_cast_for_get_loc(key)
#     682             except ValueError as err:
#
# c:\users\music\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\datetimes.py in _maybe_cast_for_get_loc(self, key)
#     708         # needed to localize naive datetimes or dates (GH 35690)
# --> 709         key = Timestamp(key)
#     710         if key.tzinfo is None:
#
# c:\users\music\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\tslibs\timestamps.pyx in pandas._libs.tslibs.timestamps.Timestamp.__new__()
#
# c:\users\music\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.convert_to_tsobject()
#
# c:\users\music\appdata\local\programs\python\python39\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion._convert_str_to_tsobject()
#
# ValueError: could not convert string to Timestamp
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8936/1855886214.py in <module>
# ----> 1 df["Direction"] != "None"
#
# c:\users\music\appdata\local\programs\python\python39\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# c:\users\music\appdata\local\programs\python\python39\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# c:\users\music\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\datetimes.py in get_loc(self, key, method, tolerance)
#     681                 key = self._maybe_cast_for_get_loc(key)
#     682             except ValueError as err:
# --> 683                 raise KeyError(key) from err
#     684
#     685         elif isinstance(key, timedelta):
#
# KeyError: 'Direction'

# %%
df = df["Direction"][df["Direction"] == "None"]

# %%
df
# Out:
# Series([], Name: Direction, dtype: object)
